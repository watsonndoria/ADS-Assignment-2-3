# %%
# Import Library
import pandas as pd

# %%
#Import csv
hr=pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
#View Data
hr.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
#Show a breakdown of distance from home by job role and attrition.
(hr.groupby(["DistanceFromHome", "Department","Attrition"]).size()
 .reset_index(name='count').sort_values(by='Department', ascending=True))
# Out:
#      DistanceFromHome       Department Attrition  count
# 0                   1  Human Resources        No      9
# 38                  8  Human Resources       Yes      1
# 94                 20  Human Resources       Yes      1
# 84                 18  Human Resources       Yes      1
# 28                  6  Human Resources       Yes      1
# ..                ...              ...       ...    ...
# 58                 11            Sales       Yes      2
# 26                  5            Sales       Yes      5
# 101                21            Sales        No      7
# 25                  5            Sales        No     16
# 137                29            Sales       Yes      1
#
# [138 rows x 4 columns]

# %%
# avg monthly income
hr.MonthlyIncome=(hr.DailyRate*hr.StandardHours).mean()

# %%
#Compare average monthly income by education and attrition.
hr.groupby(["MonthlyIncome", "Education","Attrition"]).size().reset_index(name='count')
# Out:
#    MonthlyIncome  Education Attrition  count
# 0   64198.857143          1        No    139
# 1   64198.857143          1       Yes     31
# 2   64198.857143          2        No    238
# 3   64198.857143          2       Yes     44
# 4   64198.857143          3        No    473
# 5   64198.857143          3       Yes     99
# 6   64198.857143          4        No    340
# 7   64198.857143          4       Yes     58
# 8   64198.857143          5        No     43
# 9   64198.857143          5       Yes      5

# %%
#plot a monthly income by education and attrition.
import matplotlib.pyplot as plt
plt.hist(hr.MonthlyIncome,bins,histtype='bar', rwidth=0.5)
plt.xlabel('marks')
plt.ylabel('count')
plt.title(' Grapg Histogram')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-9f0eb6e402b1> in <module>
#       1 #plot a breakdown of distance from home by job role and attrition.
#       2 import matplotlib.pyplot as plt
# ----> 3 plt.hist(hr.DistanceFromHome,bins,histtype='bar', rwidth=0.5)
#       4 plt.xlabel('marks')
#       5 plt.ylabel('count')
#
# NameError: name 'bins' is not defined
